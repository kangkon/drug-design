# %%
import pandas as pd
import os

# %%
# Import Docking output file
data = []
with open(f"./output/docking_output.txt") as merged_logfile:
    captured_data = {}
    result_table = ""
    capture_run = False # flag for capture docking run
    capture_table = False # flag for capture markdown table
    for line in merged_logfile:
        if line.startswith("[STARTRUN]"):
            capture_run = True
            splited = line.split(" ")
            lig_dir_path = splited[-1]
            captured_data["lig_id"] = os.path.basename(lig_dir_path).strip()
            captured_data["lig_dir_path"] = lig_dir_path.strip()
        if line.startswith("[ENDRUN]"):
            capture_run = False
            captured_data['table'] = result_table
            data.append(captured_data)
            captured_data = {}
            result_table = ""
        
        if line.startswith('[ENDRESULT]'):
            capture_table = False
        
        # Capturing table data
        if capture_table:
            if not line.startswith('[REMARK]'):
                result_table += line
        
        if line.startswith('[RESULT]'):
            capture_table = True

# %%
data
# Out:
# [{'lig_id': '0',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/0',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -7.7 |    0.000 |     0.000\n   2 |     -7.7 |    0.479 |     2.068\n   3 |     -7.6 |    1.953 |     7.983\n'},
#  {'lig_id': '1',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/1',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.3 |    0.000 |     0.000\n   2 |     -7.9 |    1.871 |     6.870\n   3 |     -7.8 |    2.261 |     6.602\n'},
#  {'lig_id': '2',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/2',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.3 |    0.000 |     0.000\n   2 |     -8.2 |    3.115 |     7.459\n   3 |     -8.0 |    3.116 |     7.339\n'},
#  {'lig_id': '3',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/3',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.3 |    0.000 |     0.000\n   2 |     -8.1 |    3.451 |     7.677\n   3 |     -7.7 |    1.852 |     5.909\n'},
#  {'lig_id': '4',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/4',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.5 |    0.000 |     0.000\n   2 |     -8.3 |    1.402 |     2.437\n   3 |     -7.8 |    4.208 |     7.598\n'},
#  {'lig_id': '5',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/5',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -9.0 |    0.000 |     0.000\n   2 |     -8.7 |    1.915 |     7.952\n   3 |     -8.5 |    1.885 |     6.036\n'},
#  {'lig_id': '6',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/6',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.8 |    0.000 |     0.000\n   2 |     -8.8 |    1.592 |     3.224\n   3 |     -8.5 |    1.845 |     6.915\n'},
#  {'lig_id': '7',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/7',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.6 |    0.000 |     0.000\n   2 |     -8.6 |    3.726 |     7.487\n   3 |     -8.5 |    3.806 |     6.779\n'},
#  {'lig_id': '8',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/8',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.7 |    0.000 |     0.000\n   2 |     -8.4 |    1.236 |     1.862\n   3 |     -8.2 |    1.945 |     7.060\n'},
#  {'lig_id': '9',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/9',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -7.8 |    0.000 |     0.000\n   2 |     -6.8 |    4.019 |     8.447\n   3 |     -6.8 |    1.520 |     3.161\n'},
#  {'lig_id': '10',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/10',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.7 |    0.000 |     0.000\n   2 |     -7.9 |    2.498 |     8.766\n   3 |     -7.8 |    3.770 |     7.491\n'},
#  {'lig_id': '11',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/11',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -9.3 |    0.000 |     0.000\n   2 |     -9.1 |    1.662 |     2.675\n   3 |     -8.9 |    2.642 |     7.829\n'},
#  {'lig_id': '12',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/12',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.9 |    0.000 |     0.000\n   2 |     -8.9 |    2.252 |     7.445\n   3 |     -8.3 |    2.328 |     7.376\n'},
#  {'lig_id': '13',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/13',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -7.7 |    0.000 |     0.000\n   2 |     -7.4 |    3.557 |     6.602\n   3 |     -6.9 |    3.638 |     6.278\n'},
#  {'lig_id': '14',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/14',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -7.6 |    0.000 |     0.000\n   2 |     -7.1 |    3.432 |     5.321\n   3 |     -7.0 |    3.644 |     7.702\n'},
#  {'lig_id': '15',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/15',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -9

#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.9 |    0.000 |     0.000\n   2 |     -8.4 |    1.304 |     2.106\n   3 |     -8.0 |    2.658 |    10.755\n'},
#  {'lig_id': '267',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/267',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.6 |    0.000 |     0.000\n   2 |     -8.1 |    4.142 |     5.971\n   3 |     -8.1 |    3.069 |     9.881\n'},
#  {'lig_id': '269',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/269',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.6 |    0.000 |     0.000\n   2 |     -8.2 |    1.813 |    10.108\n   3 |     -8.2 |    1.189 |     1.988\n'},
#  {'lig_id': '273',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/273',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -7.5 |    0.000 |     0.000\n   2 |     -7.5 |    2.960 |     5.904\n   3 |     -7.3 |    4.032 |     7.770\n'},
#  {'lig_id': '274',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/274',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -8.0 |    0.000 |     0.000\n   2 |     -8.0 |    4.673 |     7.889\n   3 |     -7.9 |    1.884 |     2.431\n'},
#  {'lig_id': '276',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/276',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -7.5 |    0.000 |     0.000\n   2 |     -7.4 |    1.618 |     2.186\n   3 |     -7.4 |    1.815 |     4.989\n'},
#  {'lig_id': '277',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/277',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -7.3 |    0.000 |     0.000\n   2 |     -7.3 |    2.765 |     7.430\n   3 |     -7.3 |    1.180 |     1.658\n'},
#  {'lig_id': '278',
#   'lig_dir_path': '/mnt/d/computers-in-biology/docking/runs2/7BQY/278',
#   'table': 'mode | affinity | rmsd_lb | rmsd_ub\n-----|----------|---------|--------\n   1 |     -6.3 |    0.000 |     0.000\n   2 |     -6.2 |    4.785 |     6.313\n   3 |     -5.9 |    2.117 |     5.276\n'}]

# %% [markdown]
# ### A function definition to convert markdown table to dict

# %%
def covert_table_to_dict(table):
    """
    Convert markdown table to Dictionary
    """
    table_splitted = table.split('\n', 1)
    
    if len(table_splitted) != 2:
        print("Invalid table format detected.")
        return None
    
    data = []
    # Get First Header Line
    columns = table_splitted[0].split('|')
    def rename_columns(c):
        c = c.strip().replace('.', "").replace(" ", "_")
        if c.startswith('affinity'):
            c = "affinity"
        return c
    columns = list(map(rename_columns, columns))
    # columns = [c.strip().replace('.', "").replace(" ", "_") for c in columns]
    for line in table_splitted[1].split('\n'):
        row = dict()
        if (not line.startswith('-')):
            cells = line.split('|')
            if(len(cells)) > 1:
                for i, c in enumerate(cells):
                    row[columns[i]] = float(cells[i].strip())
                data.append(row)
    return data

# %% [markdown]
# ## Create the result dataframe

# %%
result_df = pd.DataFrame()
for e in data:
    res = pd.DataFrame(covert_table_to_dict(e['table']))
    res['lig_id'] = e['lig_id']
    res['lig_dir_path'] = e['lig_dir_path']
    result_df = result_df.append(res, ignore_index=True)

result_df.head()
# Out:
#    mode  affinity  rmsd_lb  rmsd_ub lig_id  \
# 0   1.0      -7.7    0.000    0.000      0
# 1   2.0      -7.7    0.479    2.068      0
# 2   3.0      -7.6    1.953    7.983      0
# 3   1.0      -8.3    0.000    0.000      1
# 4   2.0      -7.9    1.871    6.870      1
#
#                                        lig_dir_path
# 0  /mnt/d/computers-in-biology/docking/runs2/7BQY/0
# 1  /mnt/d/computers-in-biology/docking/runs2/7BQY/0
# 2  /mnt/d/computers-in-biology/docking/runs2/7BQY/0
# 3  /mnt/d/computers-in-biology/docking/runs2/7BQY/1
# 4  /mnt/d/computers-in-biology/docking/runs2/7BQY/1

# %%
# change numeric types
numeric_columns = ["mode", "affinity", "lig_id"]
result_df[numeric_columns] = result_df[numeric_columns].apply(pd.to_numeric, errors='coerce')
result_df.dtypes
# Out:
# mode            float64
# affinity        float64
# rmsd_lb         float64
# rmsd_ub         float64
# lig_id            int64
# lig_dir_path     object
# dtype: object

# %%
# select first mode and sort ASC
result_df_m1 = result_df[result_df["mode"] == 1].sort_values(by="affinity", ascending=True)
result_df_m1
# Out:
#      mode  affinity  rmsd_lb  rmsd_ub  lig_id  \
# 270   1.0      -9.9      0.0      0.0      90
# 171   1.0      -9.7      0.0      0.0      57
# 267   1.0      -9.5      0.0      0.0      89
# 45    1.0      -9.4      0.0      0.0      15
# 708   1.0      -9.3      0.0      0.0     238
# ..    ...       ...      ...      ...     ...
# 408   1.0      -6.4      0.0      0.0     136
# 810   1.0      -6.3      0.0      0.0     278
# 189   1.0      -1.0      0.0      0.0      63
# 135   1.0      -1.0      0.0      0.0      45
# 123   1.0      -1.0      0.0      0.0      41
#
#                                           lig_dir_path
# 270  /mnt/d/computers-in-biology/docking/runs2/7BQY/90
# 171  /mnt/d/computers-in-biology/docking/runs2/7BQY/57
# 267  /mnt/d/computers-in-biology/docking/runs2/7BQY/89
# 45   /mnt/d/computers-in-biology/docking/runs2/7BQY/15
# 708  /mnt/d/computers-in-biology/docking/runs2/7BQY...
# ..                                                 ...
# 408  /mnt/d/computers-in-biology/docking/runs2/7BQY...
# 810  /mnt/d/computers-in-biology/docking/runs2/7BQY...
# 189  /mnt/d/computers-in-biology/docking/runs2/7BQY/63
# 135  /mnt/d/computers-in-biology/docking/runs2/7BQY/45
# 123  /mnt/d/computers-in-biology/docking/runs2/7BQY/41
#
# [271 rows x 6 columns]

# %% [markdown]
# ## Join the Ligand Metadata

# %%
lig_metadata = pd.read_csv("./output/ligand_dataset.csv").rename(columns={"LIG_ID": "lig_id"})
lig_metadata.head()
# Out:
#    lig_id                                             smiles  \
# 0       0  COC1=CC(=CC(OC)=C1O)C1=[O+]C2=C(C=C1OC1OC(COC(...
# 1       1  CC(=O)OCC1OC(OC2=CC3=C(O)C=C(O)C=C3[O+]=C2C2=C...
# 2       2  [H][C@]1(COC(C)=O)O[C@@]([H])(OC2=CC3=C(O)C=C(...
# 3       3  OC[C@H]1O[C@@H](OC2=CC3=C(O)C=C(O)C=C3[O+]=C2C...
# 4       4  OC[C@H]1O[C@@H](OC2=CC3=C(C=C(O)C=C3O)[O+]=C2C...
#
#                                        name  molecular_weight    formula  \
# 0  Malvidin 3-O-(6''-p-coumaroyl-glucoside)           639.580  C32H31O14
# 1  Delphinidin 3-O-(6''-acetyl-galactoside)           507.421  C23H23O13
# 2     Cyanidin 3-O-(6''-acetyl-galactoside)           491.422  C23H23O12
# 3                  Cyanidin 3-O-galactoside           449.385  C21H21O11
# 4                    Cyanidin 3-O-glucoside           449.385  C21H21O11
#
#      logP  molecular_wt_calculated  havy_atom_count  hydrogen_acceptors  \
# 0  2.6635                  639.586               46                  13
# 1  0.6584                  507.424               36                  12
# 2  0.9528                  491.425               35                  11
# 3  0.3820                  449.388               32                  10
# 4  0.3820                  449.388               32                  10
#
#    hydrogen_donors  rotatable_bonds  amide_bonds  ring_count
# 0                7               18            0           5
# 1                8               14            0           4
# 2                7               13            0           4
# 3                8               12            0           4
# 4                8               12            0           4

# %%
# Do a Left Join
df_merged = pd.merge(result_df_m1, lig_metadata, how="left", on="lig_id")
df_merged
# Out:
#      mode  affinity  rmsd_lb  rmsd_ub  lig_id  \
# 0     1.0      -9.9      0.0      0.0      90
# 1     1.0      -9.7      0.0      0.0      57
# 2     1.0      -9.5      0.0      0.0      89
# 3     1.0      -9.4      0.0      0.0      15
# 4     1.0      -9.3      0.0      0.0     238
# ..    ...       ...      ...      ...     ...
# 266   1.0      -6.4      0.0      0.0     136
# 267   1.0      -6.3      0.0      0.0     278
# 268   1.0      -1.0      0.0      0.0      63
# 269   1.0      -1.0      0.0      0.0      45
# 270   1.0      -1.0      0.0      0.0      41
#
#                                           lig_dir_path  \
# 0    /mnt/d/computers-in-biology/docking/runs2/7BQY/90
# 1    /mnt/d/computers-in-biology/docking/runs2/7BQY/57
# 2    /mnt/d/computers-in-biology/docking/runs2/7BQY/89
# 3    /mnt/d/computers-in-biology/docking/runs2/7BQY/15
# 4    /mnt/d/computers-in-biology/docking/runs2/7BQY...
# ..                                                 ...
# 266  /mnt/d/computers-in-biology/docking/runs2/7BQY...
# 267  /mnt/d/computers-in-biology/docking/runs2/7BQY...
# 268  /mnt/d/computers-in-biology/docking/runs2/7BQY/63
# 269  /mnt/d/computers-in-biology/docking/runs2/7BQY/45
# 270  /mnt/d/computers-in-biology/docking/runs2/7BQY/41
#
#                                                 smiles  \
# 0    [H][C@@]1(OC2=CC(OC(=O)C3=CC(O)=C(O)C(O)=C3)=C...
# 1    OC1C(COC(=O)\C=C\C2=CC=C(O)C=C2)OC(OC2=CC3=C(O...
# 2    O[C@@H]1CC2=C(O)C=C(O)C=C2O[C@@H]1C1=CC2=C(C(O...
# 3    COC1=CC(=CC(OC)=C1O)C1=C(O[C@@H]2O[C@H](CO)[C@...
# 4    [H][C@@]1(C)O[C@@]([H])(O[C@]2([H])[C@@]([H])(...
# ..                                                 ...
# 266  COC1=C(OC)C=C(C=C1)C1=CC(=O)C2=C(O1)C(OC)=C(OC...
# 267           CN(C)CCCSC1=CC=CC=C1NC(=O)C=CC2=CC=CC=C2
# 268  [Cl-].OC[C@H]1O[C@@H](OC2=CC(O)=CC3=[O+]C(=C(O...
# 269  [Cl-].COC1=CC(=CC(OC)=C1O)C1=[O+]C2=CC(O)=CC(O...
# 270  [Cl-].OC[C@H]1O[C@@H](OC2=CC3=C(O)C=C(O)C=C3[O...
#
#                                          name  molecular_weight      formula  \
# 0                 Theaflavin 3,3'-O-digallate           868.702    C43H32O20
# 1    Cyanidin 3-O-(6''-p-coumaroyl-glucoside)           595.528    C30H27O13
# 2                     Theaflavin 3'-O-gallate           716.598    C36H28O16
# 3                  Malvidin 3,5-O-diglucoside           655.578    C29H35O17
# 4           Kaempferol 3-O-xylosyl-rutinoside           740.659    C33H40O19
# ..                                        ...               ...          ...
# 266                                 Nobiletin           402.395     C21H22O8
# 267                               Cinanserine           340.500   C20H24N2OS
# 268            Pelargonidin 3,5-O-diglucoside           630.979  C27H31ClO15
# 269                  Malvidin 3-O-galactoside           528.890  C23H25ClO12
# 270                 Cyanidin 3-O-sambubioside           616.952  C26H29ClO15
#
#        logP  molecular_wt_calculated  havy_atom_count  hydrogen_acceptors  \
# 0    3.4742                  868.709               63                  20
# 1    2.3519                  595.533               43                  12
# 2    3.1949                  716.604               52                  16
# 3   -1.8333                  655.582               46                  16
# 4   -2.5409                  740.664               52                  19
# ..      ...                      ...              ...                 ...
# 266  3.5116                  402.399               29                   8
# 267  4.3823                  340.492               24                   3
# 268 -4.8465                  630.983               43                  14
# 269 -2.3024                  528.894               36                  11
# 270 -4.1507                  616.956               42                  14
#
#      hydrogen_donors  rotatable_bonds  amide_bonds  ring_count
# 0                 13               19            0           8
# 1                  8               15            0           5
# 2                 11               15            0           7
# 3                 10               21            0           5
# 4                 11               21            0           6
# ..               ...              ...          ...         ...
# 266                0               13            0           3
# 267                1               10            1           2
# 268               10               17            0           5
# 269                7               15            0           4
# 270               10               16            0           5
#
# [271 rows x 18 columns]

# %%
df_merged.shape
# Out:
# (271, 18)

# %% [markdown]
# ## Split Poses and Convert to PDB

# %%
import shlex, subprocess 
from datetime import datetime
import os

# %%
def split_docked_complex(destination_dir, docked_file = "results.pdbqt"):
    result_dir = os.path.join(destination_dir, "poses")
    
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    args = shlex.split(f"vina_split --input {os.path.join(destination_dir, docked_file)}  --ligand pose_ --flex chain_")
    process = subprocess.Popen(
        args, 
        stdout=subprocess.PIPE, 
        stderr=subprocess.PIPE,
        cwd=result_dir # Set current working directory
    )
    output, error = process.communicate()
    if error:
        print("Error: ", error.decode("utf-8")) 
    else:
        print(output.decode("utf-8"))

# %%
selected_ligands = ["90", "57", "89"]

# %%
# !pwd
# Out:
# /mnt/d/computers-in-biology/notebooks

# %%
# Iterate over selected ligand ids and split
for l in selected_ligands:
    split_docked_complex(f"/mnt/d/computers-in-biology/notebooks/data/docking_results/{l}")

# %% [markdown]
# ### Create complex on Pose 1 and Convert to PDB

# %%
from pymol import cmd
for l in selected_ligands:
    receptor = f"/mnt/d/computers-in-biology/notebooks/data/docking_results/{l}/7BQY_final.pdbqt"
    ligand = f"/mnt/d/computers-in-biology/notebooks/data/docking_results/{l}/poses/pose_1.pdbqt"
    output = f"/mnt/d/computers-in-biology/notebooks/data/docking_results/{l}/poses/pose_1_complex.pdb"
    
    cmd.delete('all')
    cmd.load(receptor, "receptor")
    #cmd.alter('name receptor', 'chain="A"')
    cmd.load(ligand, "ligand")
    #cmd.alter('name ligand', 'chain="B"')
    #cmd.png('./test2.png', 1000, 1000)
    cmd.set('pdb_conect_all', 'on')
    cmd.save(output)
    #cmd.quit()
# Out:
#  PyMOL not running, entering library mode (experimental)
